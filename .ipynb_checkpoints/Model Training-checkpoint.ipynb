# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import svm

# %%
df = pd.read_csv("20162017_data.csv")

# %%
df
# Out:
#                 PLAYER TEAM  AGE  GAMES PLAYED  WINS  LOSSES  MINUTES PLAYED  \
# 0      DeAndre' Bembry  ATL   22            38    20      18             9.8
# 1      Dennis Schroder  ATL   23            79    42      37            31.5
# 2        Dwight Howard  ATL   31            74    37      37            29.7
# 3       Ersan Ilyasova  ATL   30            82    35      47            26.1
# 4            Gary Neal  ATL   32             2     1       1             9.2
# 5        Jose Calderon  ATL   35            41    15      26            13.1
# 6        Kent Bazemore  ATL   27            73    39      34            26.9
# 7       Kris Humphries  ATL   32            56    31      25            12.3
# 8      Lamar Patterson  ATL   25             5     1       4             8.1
# 9      Malcolm Delaney  ATL   28            73    37      36            17.1
# 10       Mike Dunleavy  ATL   36            53    34      19            15.9
# ...
